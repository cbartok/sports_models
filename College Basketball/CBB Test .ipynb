# %%
from sportsreference.ncaab.teams import Teams
from sportsreference.ncaab.schedule import Schedule
from sportsreference.ncaab.boxscore import Boxscore, Boxscores
import pandas as pd

# %%
Schedule('duke', 2016).dataframe
# Out:
#                                                        arena  \
# 2015-11-13-duke                       Cameron Indoor Stadium
# 2015-11-14-duke                       Cameron Indoor Stadium
# 2015-11-17-duke                                United Center
# 2015-11-20-virginia-commonwealth  Madison Square Garden (IV)
# 2015-11-22-duke                   Madison Square Garden (IV)
# 2015-11-25-duke                       Cameron Indoor Stadium
# 2015-11-29-duke                       Cameron Indoor Stadium
# 2015-12-02-duke                       Cameron Indoor Stadium
# 2015-12-05-duke                       Cameron Indoor Stadium
# 2015-12-15-duke                       Cameron Indoor Stadium
# 2015-12-19-duke                   Madison Square Garden (IV)
# 2015-12-28-duke                       Cameron Indoor Stadium
# 2015-12-30-duke                       Cameron Indoor Stadium
# 2016-01-02-boston-college              Silvio O. Conte Forum
# ...
